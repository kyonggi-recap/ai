London, Thursday, May 22, 2025, after a British court blocked the U.K. from transferring sovereignty over the Chagos Islands to Mauritius hours before the agreement was due to be signed. (AP Photo/Thomas Krych) People demonstrate outside the Foreign Office in London, Thursday, May 22, 2025, after a British court blocked the U.K. from transferring sovereignty over the Chagos Islands to Mauritius hours before the agreement was due to be signed. (AP Photo/Thomas Krych) Share The deal establishes a trust fund to benefit the Chagossians and says “Mauritius is free to implement a program of resettlement” on the islands, other than Diego Garcia. But it does not require the residents to be resettled. Pompe said it was “a very sad day,“ but vowed to continue fighting. “The rights we are asking for now, we have been fighting for for 60 years,” she said outside the High Court. “Mauritius is not going to give that to us.” One of the last remnants of the British Empire, the Chagos Islands have been under U.K. control since 1814. Britain split the islands away from Mauritius, a former British colony, in 1965, three years before Mauritius gained independence. Britain from the islands in the 1960s and 1970s so the U.S. military could build the Diego Garcia base, which has supported U.S. operations from Vietnam to Iraq and Afghanistan. It has facilities to accommodate nuclear submarines, aircraft carriers and large airplanes, and plays a key role in U.S. intelligence-gathering. Mauritius has long contested Britain’s claim to the archipelago, and the United Nations and its top court have , around 2,100 kilometers (1,250 miles) southwest of the islands. In a non-binding 2019 opinion, the when it agreed to end colonial rule in the late 1960s. Starmer said that “we had to act now because the base was under threat.” He said Mauritius is likely to have taken Britain to court within weeks and the U.K. had no “realistic prospect of success.” Britain’s defense ministry said the deal includes strong protections, including a 24-mile (39 kilometer) exclusion zone around Diego Garcia, a U.K. veto over development on the wider islands and a ban on foreign security forces on the islands. Negotiations on handing the islands to Mauritius began in 2022 under the previous Conservative government and resumed after Starmer’s Labour Party was elected in July. A draft agreement was struck in October, but was delayed by a change of government in Mauritius and quarrels over how much the U.K. should pay to lease the base. Britain also paused to consult Presient Donald Trump’s administration after the change of government in Washington. Secretary of State Marco Rubio welcomed the agreement, saying it “secures the long-term, stable, and effective operation” of the Diego Garcia base, ”a critical asset for regional and global security. “ ___ Associated Press writer Matthew Lee in Washington contributed. Lawless is an Associated Press reporter covering U.K. politics and more. She is based in London."

# %% [markdown]
# 위에꺼는 data를 그냥 넣으면 됨 뉴스 기사 넣어도 될듯 , 요약된거 말고

# %%
pip install openai
import openai
openai.api_key = "" 
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=[text],
        model=model
    )
    return response.data[0].embedding
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#원하는 data에 get_embedding 을 거쳐서 embedding vetor로 만들기 
embedding_data = get_embedding(data)

# %%
import requests, json
from requests.auth import HTTPBasicAuth

# OpenSearch 설정
#https://search-arncapstion-xb744bq42f6atx7if7z3gn7i5e.ap-northeast-2.es.amazonaws.com
#https://search-arncapstion-xb744bq42f6atx7if7z3gn7i5e.ap-northeast-2.es.amazonaws.com/fake-news-rag/_search
#endpoint 바뀜
ENDPOINT = "https://search-arncapstion-xb744bq42f6atx7if7z3gn7i5e.ap-northeast-2.es.amazonaws.com/fake-news-rag/_search"
AUTH     = HTTPBasicAuth("dongoh", "Aws1234!!")

# 검색 쿼리
body = {
  "size": 3,
  "query": {
    "knn": {
      "embedding": {
        "vector": embedding_data,  # 여기에 1536차원 벡터 입력
        "k": 3
      }
    }
  }
}

# 요청 실행
r = requests.get(ENDPOINT, auth=AUTH, json=body)
resp = r.json()

# 유사 문서들의 임베딩 값 수집
similar_embeddings = []

for hit in resp["hits"]["hits"]:
    embedding = hit["_source"]["embedding"]
    similar_embeddings.append(embedding)

#embedding_data,similar_embeddings[0],similar_embeddings[1],similar_embeddings[2] 이렇게 4개가 총 모델의 입력으로 들어가야함.

# %%
import numpy as np
import boto3

query = embedding_data  
ctx1 = similar_embeddings[0]
ctx2 = similar_embeddings[1]
ctx3 = similar_embeddings[2]

# 3. 전체 입력 배열 생성: (1, 4, 1536)
example_input = np.array([ [query, ctx1, ctx2, ctx3] ])  # shape: (1, 4, 1536)

sm_runtime = boto3.client("sagemaker-runtime", region_name="ap-northeast-2")

# 4. 엔드포인트 호출
response = sm_runtime.invoke_endpoint(
    EndpointName="fake-true",  # ← 이거는 고정할거임.
    ContentType="application/json",
    Body=json.dumps(example_input.tolist())
)

# 5. 결과 파싱
result = json.loads(response["Body"].read())
print("예측 결과:", result)
