# %%
import pandas as pd

# CSV 파일 로드
df = pd.read_csv("7500_embedding_after_5part/all_parts_concated.csv")

# 필수 컬럼 존재 확인
assert "text" in df.columns
assert "label" in df.columns
assert "embedding" in df.columns  # 문자열로 저장되었을 가능성 있음

# %%
print(df.iloc[0]["embedding"])
print(type(df.iloc[0]["embedding"]))

# %%
import ast
df["embedding"] = df["embedding"].apply(ast.literal_eval)

# %%
print(df.iloc[0]["embedding"])
print(type(df.iloc[0]["embedding"]))
